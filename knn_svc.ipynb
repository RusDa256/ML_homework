# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('full_data.csv', sep=',', engine='python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
data.tail()
# Out:
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 4976    Male  41.0             0              0           No   Private
# 4977    Male  40.0             0              0          Yes   Private
# 4978  Female  45.0             1              0          Yes  Govt_job
# 4979    Male  40.0             0              0          Yes   Private
# 4980  Female  80.0             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0

# %%
print(data.shape)
print(data.columns)
# Out:
# (4981, 11)
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
data[['age', 'avg_glucose_level', 'bmi']].describe()
# Out:
#                age  avg_glucose_level          bmi
# count  4981.000000        4981.000000  4981.000000
# mean     43.419859         105.943562    28.498173
# std      22.662755          45.075373     6.790464
# min       0.080000          55.120000    14.000000
# 25%      25.000000          77.230000    23.700000
# 50%      45.000000          91.850000    28.100000
# 75%      61.000000         113.860000    32.600000
# max      82.000000         271.740000    48.900000

# %%
data.corr()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.278120       0.264852           0.236763
# hypertension       0.278120      1.000000       0.111974           0.170028
# heart_disease      0.264852      0.111974       1.000000           0.166847
# avg_glucose_level  0.236763      0.170028       0.166847           1.000000
# bmi                0.373703      0.158762       0.060926           0.186348
# stroke             0.246478      0.131965       0.134610           0.133227
#
#                         bmi    stroke
# age                0.373703  0.246478
# hypertension       0.158762  0.131965
# heart_disease      0.060926  0.134610
# avg_glucose_level  0.186348  0.133227
# bmi                1.000000  0.056926
# stroke             0.056926  1.000000

# %%
data.sort_values(by='age', ascending=True)[0:150]
# Out:
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 3057    Male  0.08             0              0           No  children
# 1487  Female  0.08             0              0           No  children
# 3363    Male  0.16             0              0           No  children
# 3996    Male  0.24             0              0           No  children
# 3148    Male  0.24             0              0           No  children
# ...      ...   ...           ...            ...          ...       ...
# 4075    Male  2.00             0              0           No  children
# 2052    Male  2.00             0              0           No  children
# 1320    Male  2.00             0              0           No  children
# 3934  Female  2.00             0              0           No  children
# 899   Female  2.00             0              0           No  children
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 3057          Rural              70.33  16.9        Unknown       0
# 1487          Urban             139.67  14.1        Unknown       0
# 3363          Urban             114.71  17.4        Unknown       0
# 3996          Urban              57.09  19.4        Unknown       0
# 3148          Urban              89.28  14.2        Unknown       0
# ...             ...                ...   ...            ...     ...
# 4075          Rural              76.12  16.8        Unknown       0
# 2052          Rural             112.66  14.2        Unknown       0
# 1320          Urban              80.98  19.9        Unknown       0
# 3934          Rural              77.72  19.8        Unknown       0
# 899           Rural             165.11  18.0        Unknown       0
#
# [150 rows x 11 columns]

# %%
data[data['age'] <=35]['age'] #их нужно удалить
# Out:
# 148     32.00
# 205     14.00
# 208      3.00
# 210      8.00
# 214     32.00
#         ...
# 4960    18.00
# 4962     3.00
# 4963    20.00
# 4973     1.32
# 4975    31.00
# Name: age, Length: 1841, dtype: float64

# %%
data = data[data['age'] >= 35]

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [3193 rows x 11 columns]

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data['bmi'],
            data['age'],
            alpha = 0.15,
            color = 'b')

plt.xlabel('bmi')
plt.xticks(range(50))
plt.xlim(14, 50)
plt.ylabel('age')
plt.grid()

# %% [markdown]
# # Готовим данные

# %%
data = data.astype({'age': np.int32})

# %%
data.at[data['gender'] == 'Male', 'gender'] = 0
data.at[data['gender'] == 'Female', 'gender'] = 1

# %%
data.at[data['ever_married'] == 'Yes', 'ever_married'] = 1
data.at[data['ever_married'] == 'No', 'ever_married'] = 0

# %%
data.at[data['Residence_type'] == 'Urban', 'Residence_type'] = 1
data.at[data['Residence_type'] == 'Rural', 'Residence_type'] = 0

# %%
data['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
data.at[data['smoking_status'] == 'formerly smoked', 'smoking_status'] = 1
data.at[data['smoking_status'] == 'never smoked', 'smoking_status'] = 2
data.at[data['smoking_status'] == 'smokes', 'smoking_status'] = 3
data.at[data['smoking_status'] == 'Unknown', 'smoking_status'] = 0

# %%
data['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job'], dtype=object)

# %%
data.at[data['work_type'] == 'Private', 'work_type'] = 1
data.at[data['work_type'] == 'Self-employed', 'work_type'] = 2
data.at[data['work_type'] == 'Govt_job', 'work_type'] = 3

# %%
data
# Out:
#      gender  age  hypertension  heart_disease ever_married work_type  \
# 0         0   67             0              1            1         1
# 1         0   80             0              1            1         1
# 2         1   49             0              0            1         1
# 3         1   79             1              0            1         2
# 4         0   81             0              0            1         1
# ...     ...  ...           ...            ...          ...       ...
# 4976      0   41             0              0            0         1
# 4977      0   40             0              0            1         1
# 4978      1   45             1              0            1         3
# 4979      0   40             0              0            1         1
# 4980      1   80             1              0            1         1
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0                 1             228.69  36.6              1       1
# 1                 0             105.92  32.5              2       1
# 2                 1             171.23  34.4              3       1
# 3                 0             174.12  24.0              2       1
# 4                 1             186.21  29.0              1       1
# ...             ...                ...   ...            ...     ...
# 4976              0              70.15  29.8              1       0
# 4977              1             191.15  31.1              3       0
# 4978              0              95.02  31.8              3       0
# 4979              0              83.94  30.0              3       0
# 4980              1              83.75  29.1              2       0
#
# [3193 rows x 11 columns]

# %%
data.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_2892c_" ><thead>    <tr>        <th class="col_heading level0 col0" >gender</th>        <th class="col_heading level0 col1" >age</th>        <th class="col_heading level0 col2" >hypertension</th>        <th class="col_heading level0 col3" >heart_disease</th>        <th class="col_heading level0 col4" >ever_married</th>        <th class="col_heading level0 col5" >work_type</th>        <th class="col_heading level0 col6" >Residence_type</th>        <th class="col_heading level0 col7" >avg_glucose_level</th>        <th class="col_heading level0 col8" >bmi</th>        <th class="col_heading level0 col9" >smoking_status</th>        <th class="col_heading level0 col10" >stroke</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2892c_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_2892c_row0_col1" class="data row0 col1" >67</td>
#                         <td id="T_2892c_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_2892c_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_2892c_row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_2892c_row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_2892c_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_2892c_row0_col7" class="data row0 col7" >228.690000</td>
#                         <td id="T_2892c_row0_col8" class="data row0 col8" >36.600000</td>
#                         <td id="T_2892c_row0_col9" class="data row0 col9" >1</td>
#                         <td id="T_2892c_row0_col10" class="data row0 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_2892c_row1_col1" class="data row1 col1" >80</td>
#                         <td id="T_2892c_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_2892c_row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_2892c_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_2892c_row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_2892c_row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_2892c_row1_col7" class="data row1 col7" >105.920000</td>
#                         <td id="T_2892c_row1_col8" class="data row1 col8" >32.500000</td>
#                         <td id="T_2892c_row1_col9" class="data row1 col9" >2</td>
#                         <td id="T_2892c_row1_col10" class="data row1 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_2892c_row2_col1" class="data row2 col1" >49</td>
#                         <td id="T_2892c_row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_2892c_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_2892c_row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_2892c_row2_col5" class="data row2 col5" >1</td>
#                         <td id="T_2892c_row2_col6" class="data row2 col6" >1</td>
#                         <td id="T_2892c_row2_col7" class="data row2 col7" >171.230000</td>
#                         <td id="T_2892c_row2_col8" class="data row2 col8" >34.400000</td>
#                         <td id="T_2892c_row2_col9" class="data row2 col9" >3</td>
#                         <td id="T_2892c_row2_col10" class="data row2 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_2892c_row3_col1" class="data row3 col1" >79</td>
#                         <td id="T_2892c_row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_2892c_row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_2892c_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_2892c_row3_col5" class="data row3 col5" >2</td>
#                         <td id="T_2892c_row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_2892c_row3_col7" class="data row3 col7" >174.120000</td>
#                         <td id="T_2892c_row3_col8" class="data row3 col8" >24.000000</td>
#                         <td id="T_2892c_row3_col9" class="data row3 col9" >2</td>
#                         <td id="T_2892c_row3_col10" class="data row3 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_2892c_row4_col1" class="data row4 col1" >81</td>
#                         <td id="T_2892c_row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_2892c_row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_2892c_row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_2892c_row4_col5" class="data row4 col5" >1</td>
#                         <td id="T_2892c_row4_col6" class="data row4 col6" >1</td>
#                         <td id="T_2892c_row4_col7" class="data row4 col7" >186.210000</td>
#                         <td id="T_2892c_row4_col8" class="data row4 col8" >29.000000</td>
#                         <td id="T_2892c_row4_col9" class="data row4 col9" >1</td>
#                         <td id="T_2892c_row4_col10" class="data row4 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_2892c_row5_col1" class="data row5 col1" >74</td>
#                         <td id="T_2892c_row5_col2" class="data row5 col2" >1</td>
#                         <td id="T_2892c_row5_col3" class="data row5 col3" >1</td>
#                         <td id="T_2892c_row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_2892c_row5_col5" class="data row5 col5" >1</td>
#                         <td id="T_2892c_row5_col6" class="data row5 col6" >0</td>
#                         <td id="T_2892c_row5_col7" class="data row5 col7" >70.090000</td>
#                         <td id="T_2892c_row5_col8" class="data row5 col8" >27.400000</td>
#                         <td id="T_2892c_row5_col9" class="data row5 col9" >2</td>
#                         <td id="T_2892c_row5_col10" class="data row5 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row6_col0" class="data row6 col0" >1</td>
#                         <td id="T_2892c_row6_col1" class="data row6 col1" >69</td>
#                         <td id="T_2892c_row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_2892c_row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_2892c_row6_col4" class="data row6 col4" >0</td>
#                         <td id="T_2892c_row6_col5" class="data row6 col5" >1</td>
#                         <td id="T_2892c_row6_col6" class="data row6 col6" >1</td>
#                         <td id="T_2892c_row6_col7" class="data row6 col7" >94.390000</td>
#                         <td id="T_2892c_row6_col8" class="data row6 col8" >22.800000</td>
#                         <td id="T_2892c_row6_col9" class="data row6 col9" >2</td>
#                         <td id="T_2892c_row6_col10" class="data row6 col10" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2892c_row7_col0" class="data row7 col0" >1</td>
#                         <td id="T_2892c_row7_col1" class="data row7 col1" >78</td>
#                         <td id="T_2892c_row7_col2" class="data row7 col2" >0</td>
#                         <td id="T_2892c_row7_col3" class="data row7 col3" >0</td>
#                         <td id="T_2892c_row7_col4" class="data row7 col4" >1</td>
#                         <td id="T_2892c_row7_col5"

# %% [markdown]
# # X и y

# %%
X = data.drop('stroke', axis = 1) # выбрасываем столбец 'class'
y = data['stroke']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
X = X.to_numpy()

# %%
y = np.array(y)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (3193, 10)
# (3193,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train = X_train.shape[0]
N_test = X_test.shape[0]

print(N_train, N_test)
# Out:
# 2235 958

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_test_predict = knn.predict(X_test)
err_test  = np.mean(y_test  != y_test_predict)

# %%
err_test
# Out:
# 0.08663883089770355

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[875   0]
#  [ 83   0]]

# %% [markdown]
# # Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 7, 10, 14, 17, 20,25]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.07248158231902624 14

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc = SVC(gamma='auto')
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.04742729306487696 0.08663883089770355

# %%
from sklearn.model_selection import GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC(gamma='auto')
grid = GridSearchCV(svc, cv=3, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# 0.0724832214765101 1e-05

# %% [markdown]
# # Таким образом, можно сделать вывод, что после подбора параметров, проценты ошибок на knn и svc равны 7,2%

# %% [markdown]
# Мы добились результата 92,8% правильных результатов на тестовой выборке.
